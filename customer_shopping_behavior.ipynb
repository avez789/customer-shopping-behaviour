# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\customer-trends-data-analysis-SQL-Python-PowerBI-main\customer-trends-data-analysis-SQL-Python-PowerBI-main\customer_shopping_behavior.csv")

# %%
df.describe(include = "all")
# Out:
#         customer_id          age gender item_purchased  category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         purchase_amount_(usd) location  size  color  season  review_rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
#review rating have some null value so using midian we can take higer value and lower value of category and fix the missing values of review rating

# %%
df['Review Rating'] = df.groupby("Category")['Review Rating'].transform(lambda x:x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns = df.columns.str.lower() 
df.columns = df.columns.str.replace(" ","_")  #lower and remove the gap of the columns

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
df.rename(columns = {'purchase_amount_(usd)':'purchase amount'},inplace = True)

# %%
df.rename(columns={'Purchase Amount (USD)':'purchase_amount'},inplace = True)

# %%
df.isnull().sum()
# Out:
# customer_id               0
# age                       0
# gender                    0
# item_purchased            0
# category                  0
# purchase amount           0
# location                  0
# size                      0
# color                     0
# season                    0
# review_rating             0
# subscription_status       0
# shipping_type             0
# discount_applied          0
# promo_code_used           0
# previous_purchases        0
# payment_method            0
# frequency_of_purchases    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
#create the columns into 4 age group
labels = ["young Age","adult","middle_age","senior"]
df["age_group"] = pd.qcut(df["age"],q =4,labels = labels)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
df[['age','age_group']]
# Out:
#       age   age_group
# 0      55  middle_age
# 1      19   young Age
# 2      50  middle_age
# 3      21   young Age
# 4      45  middle_age
# ...   ...         ...
# 3895   40       adult
# 3896   52  middle_age
# 3897   46  middle_age
# 3898   44       adult
# 3899   52  middle_age
#
# [3900 rows x 2 columns]

# %%
#create columns purchase_frequency_days
frequency_mapping = {
                     "Fortnightly":14,
                     "Weekly":7,
                     "Monthly":30,
                     "Quarterly":90,
                     "Bi-Weekly":14,
                     "Annually":365,
                    "Every 3 Months":90
}
df["purchased_frequency_days"] = df["frequency_of_purchases"].map(frequency_mapping)

# %%
df.head(1)
# Out:
#    customer_id  age gender item_purchased  category  purchase amount  \
# 0            1   55   Male         Blouse  Clothing               53
#
#    location size color  season  review_rating subscription_status  \
# 0  Kentucky    L  Gray  Winter            3.1                 Yes
#
#   shipping_type discount_applied promo_code_used  previous_purchases  \
# 0       Express              Yes             Yes                  14
#
#   payment_method frequency_of_purchases   age_group  purchased_frequency_days
# 0          Venmo            Fortnightly  middle_age                        14

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchased_frequency_days'],
#       dtype='object')

# %%
df[["discount_applied","promo_code_used"]].head(4)

# %%
#the both columns hold the same value do delate one columns
(df["discount_applied"] == df["promo_code_used"]).all()

# %%
df.drop("promo_code_used",axis =1 ,inplace = True)

# %%
df.head(10)
# Out:
#    customer_id  age gender item_purchased     category  purchase amount  \
# 0            1   55   Male         Blouse     Clothing               53
# 1            2   19   Male        Sweater     Clothing               64
# 2            3   50   Male          Jeans     Clothing               73
# 3            4   21   Male        Sandals     Footwear               90
# 4            5   45   Male         Blouse     Clothing               49
# 5            6   46   Male       Sneakers     Footwear               20
# 6            7   63   Male          Shirt     Clothing               85
# 7            8   27   Male         Shorts     Clothing               34
# 8            9   26   Male           Coat    Outerwear               97
# 9           10   57   Male        Handbag  Accessories               31
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# ...

# %%
# !pip install mysql-connector-python sqlalchemy pymysql

# %%
df.head(5)
# Out:
#    customer_id  age gender item_purchased  category  purchase amount  \
# 0            1   55   Male         Blouse  Clothing               53
# 1            2   19   Male        Sweater  Clothing               64
# 2            3   50   Male          Jeans  Clothing               73
# 3            4   21   Male        Sandals  Footwear               90
# 4            5   45   Male         Blouse  Clothing               49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    shipping_type discount_applied  previous_purchases payment_method  \
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# connect to your Diwali database
engine = create_engine("mysql+pymysql://root:root@localhost:3306/cust")

# read your CSV file
df = pd.read_csv(r"C:\Users\Admin\Desktop\customer-trends-data-analysis-SQL-Python-PowerBI-main\customer-trends-data-analysis-SQL-Python-PowerBI-main\customer_shopping_behavior.csv")

# store CSV into ONE table (you choose name)
df.to_sql(name="customer", con=engine, if_exists="replace", index=False)
print("success")
# Out:
# success

# %%
#clean columns name;
df.columns = df.columns.str.strip().str.replace(" ","_").str.lower()
#remove wrong dublicate headers rows(if any)
df = df[df.iloc[:,0] != df.columns[0]]   
#rename the columns 
df.rename(columns={"purchase_amount_(usd)" : "purchase_amount"},inplace = True)
# puts the one columns into 4 diffrent parts 
labels = ["young Age","adult","middle_age","senior"]
df["age_group"] = pd.qcut(df["age"],q =4,labels = labels)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
df.rename(columns={"purchase_amount_(usd)" : "purchase_amount"},inplace = True)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases', 'age_group'],
#       dtype='object')

# %%
#What is the total revenue generated by male  vs female customers
result  = pd.read_sql("select gender, sum(purchase_amount) as revenue  from customer group by gender",engine)
print(result)
# Out:
#    gender   revenue
# 0    Male  157890.0
# 1  Female   75191.0

# %%
esult  = pd.read_sql("select gender, sum(purchase_amount) as revenue  from customer group by gender",engine)
print(result)
# Out:
#    gender   revenue
# 0    Male  157890.0
# 1  Female   75191.0

# %%
labels = ["young Age","adult","middle_age","senior"]
df["age_group"] = pd.qcut(df["age"],q =4,labels = labels)

# %%
labels =labels = ["young Age","adult","middle_age","senior"]
df["age_group"] = pd.qcut(df[age]),q = 4,label =label)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases', 'age_group'],
#       dtype='object')

# %%
s
